# %%
import pandas as pd
pd.options.display.max_columns = 200
pd.options.display.max_rows = 200
import category_encoders as ce
import pandas as pd
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
X_train = pd.read_csv('train_features.csv')
X_test = pd.read_csv('test_features.csv')
y_train = pd.read_csv('train_labels.csv')['charged_off']
sample_submission = pd.read_csv('sample_submission.csv')

X_train.shape, X_test.shape, y_train.shape
# Out:
# ((37745, 103), (9437, 103), (37745,))

# %%
X_train.head()
# Out:
#       id  member_id  loan_amnt  funded_amnt        term int_rate  installment  \
# 0  43373        NaN      12000        12000   36 months   16.02%       422.01
# 1  24414        NaN       6300         6300   36 months   14.07%       215.54
# 2  46723        NaN       4500         4500   36 months    7.21%       139.38
# 3  24878        NaN      12000        12000   36 months    9.44%       384.06
# 4  39038        NaN      12000        12000   36 months   22.35%       460.47
#
#   grade sub_grade                    emp_title emp_length home_ownership  \
# 0     C        C5                       Driver    4 years       MORTGAGE
# 1     C        C3                     GMP Lead    4 years           RENT
# 2     A        A3                    Accounts     3 years           RENT
# 3     B        B1  Client Processing Associate  10+ years       MORTGAGE
# 4     D        D5       Construction Operator   10+ years       MORTGAGE
#
# ...

# %%
list(X_train)
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'application_type',
#  'annual_inc_joint',
#  'dti_joint',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'open_acc_6m',
#  'open_act_il',
#  'open_il_12m',
#  'open_il_24m',
#  'mths_since_rcnt_il',
#  'total_bal_il',
#  'il_util',
#  'open_rv_12m',
#  'open_rv_24m',
#  'max_bal_bc',
#  'all_util',
#  'total_rev_hi_lim',
#  'inq_fi',
#  'total_cu_tl',
#  'inq_last_12m',
#  'acc_open_past_24mths',
# ...

# %%
def wrangle(X):
    X = X.copy()
    
    # Drop some columns
    X = X.drop('id', axis = 1) # id is random
    X = X.drop(columns = ['member_id', 'url', 'desc']) #All null
    X = X.drop(columns = ['disbursement_method']) #All null
    X = X.drop(columns = 'title')  # Duplicate of purpose
    X = X.drop(columns ='grade') # Duplicate of subgrade
    
    # Transform subgrade from A! to 1.1 - 7.5
    def wrangle_sub_grade(x):
        first_digit = ord(x[0]) - 64
        second_digit = int(x[1])
        return first_digit + second_digit/10
    
    X['sub_grade'] = X['sub_grade'].apply(wrangle_sub_grade)
    
    #Convert percentages from strings to floats
    X['int_rate'] = X['int_rate'].str.strip('%').astype(float)
    X['revol_util'] = X['revol_util'].str.strip('%').astype(float)
    
    # Transform earliest_cr_line to an integer... how many days it has been open
    X['earliest_cr_line'] = pd.to_datetime(X['earliest_cr_line'], infer_datetime_format=True)
    X['earliest_cr_line'] = pd.Timestamp.today() - X['earliest_cr_line']
    X['earliest_cr_line'] = X['earliest_cr_line'].dt.days
    
    # Create features for three employee titiles... teacher, manager, owner
    X['emp_title'] = X['emp_title'].str.lower()
    X['emp_title_teacher'] = X['emp_title'].str.contains('teacher', na=False)
    X['emp_title_manager'] = X['emp_title'].str.contains('manager', na=False)
    X['emp_title_owner'] = X['emp_title'].str.contains('owner', na=False)
    
    # Drop categoricals with hidh cardinality
    X = X.drop(columns=['emp_title', 'zip_code'])
    
    # Transform features with many nulls to binary flags
    many_nulls = ['sec_app_mths_since_last_major_derog',
                  'sec_app_revol_util',
                  'sec_app_earliest_cr_line',
                  'sec_app_mort_acc',
                  'dti_joint',
                  'sec_app_collections_12_mths_ex_med',
                  'sec_app_chargeoff_within_12_mths',
                  'sec_app_num_rev_accts',
                  'sec_app_open_act_il',
                  'sec_app_open_acc',
                  'revol_bal_joint',
                  'annual_inc_joint',
                  'sec_app_inq_last_6mths',
                  'mths_since_last_record',
                  'mths_since_recent_bc_dlq',
                  'mths_since_last_major_derog',
                  'mths_since_recent_revol_delinq',
                  'mths_since_last_delinq',
                  'il_util',
                  'emp_length',
                  'mths_since_recent_inq',
                  'mo_sin_old_il_acct',
                  'mths_since_rcnt_il',
                  'num_tl_120dpd_2m',
                  'bc_util',
                  'percent_bc_gt_75',
                  'bc_open_to_buy',
                  'mths_since_recent_bc']
    
    
    for col in many_nulls:
        X[col] = X[col].isnull()
        
    # for features with few nulls, do mean imputation
    for col in X:
        if X[col].isnull().sum() > 0:
            X[col] = X[col].fillna(X[col].mean())
            
    # return wrangled data frame
    return X

X_train = wrangle(X_train)
X_test = wrangle(X_test)
X_train.shape, X_test.shape
# Out:
# ((37745, 97), (9437, 97))

# %%
null_counts = X_train.isnull().sum()
all(null_counts == 0)
# Out:
# True

# %%
X_train.head()
# Out:
#    loan_amnt  funded_amnt        term  int_rate  installment  sub_grade  \
# 0      12000        12000   36 months     16.02       422.01        3.5
# 1       6300         6300   36 months     14.07       215.54        3.3
# 2       4500         4500   36 months      7.21       139.38        1.3
# 3      12000        12000   36 months      9.44       384.06        2.1
# 4      12000        12000   36 months     22.35       460.47        4.5
#
#    emp_length home_ownership  annual_inc             purpose addr_state  \
# 0       False       MORTGAGE     81000.0  debt_consolidation         NC
# 1       False           RENT     39000.0  debt_consolidation         CA
# 2       False           RENT     78000.0  debt_consolidation         CA
# 3       False       MORTGAGE     62000.0  debt_consolidation         OH
# 4       False       MORTGAGE     70000.0  debt_consolidation         TX
#
#      dti  delinq_2yrs  earliest_cr_line  inq_last_6mths  \
# ...

# %%
# Decision Tree

pipe = make_pipeline(
    ce.OrdinalEncoder(), 
    DecisionTreeClassifier(max_depth=5, class_weight='balanced')
)

cross_val_score(pipe, X_train, y_train, cv=5, scoring='roc_auc')
# Out:
# array([0.70297128, 0.70043521, 0.69332495, 0.68879982, 0.68917646])

# %%
# Random Forest Improves ROC AUC compared to Decision Tree

from sklearn.ensemble import RandomForestClassifier

pipe = make_pipeline(
       ce.OrdinalEncoder(),
       RandomForestClassifier(
       n_estimators = 100,
       class_weight = 'balanced',
       min_samples_leaf = .005,
       oob_score = True,
       n_jobs = -1))

cross_val_score(pipe, X_train, y_train, cv=5, scoring='roc_auc', verbose = 10)
# Out:
# [CV]  ................................................................
# [CV] ....................... , score=0.7281089345151319, total=   2.5s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [CV] ....................... , score=0.7297725112679022, total=   2.4s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.9s remaining:    0.0s
# [CV] ....................... , score=0.7217822900649804, total=   2.4s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.3s remaining:    0.0s
# [CV] ....................... , score=0.7273609467190894, total=   2.1s
# [CV]  ................................................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    9.4s remaining:    0.0s
# ...

# %%
import category_encoders as ce
from sklearn.model_selection import cross_val_predict
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier

pipe.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('ordinalencoder', OrdinalEncoder(cols=['term', 'home_ownership', 'purpose', 'addr_state', 'initial_list_status', 'application_type'],
#         drop_invariant=False, handle_unknown='impute', impute_missing=True,
#         mapping=[{'col': 'term', 'mapping': [(' 36 months', 1), (' 60 months', 2)]...mators=100, n_jobs=-1, oob_score=True, random_state=None,
#             verbose=0, warm_start=False))])

# %%
sample_submission = pd.read_csv('sample_submission.csv') 
submission = sample_submission.copy() 
submission['charged_off'] = pipe.predict_proba(X_test)[:, 1] 
submission.to_csv('submission-1.csv', index=False)

# %%
from sklearn.metrics import roc_auc_score

max_depths = list(range(2, 12, 2)) + [None]

for max_depth in max_depths:
    
    pipe = make_pipeline(
        ce.OrdinalEncoder(), 
        RandomForestClassifier(
            n_estimators=100, 
            class_weight='balanced', 
            max_depth=max_depth, 
            oob_score=True, 
            n_jobs=-1
        )
    )
        
    pipe.fit(X_train, y_train)
    y_pred_proba = pipe.named_steps['randomforestclassifier'].oob_decision_function_[:, 1]
    print('Max Depth:', max_depth)
    print('ROC AUC, OOB:', roc_auc_score(y_train, y_pred_proba))
# Out:
# Max Depth: 2
# ROC AUC, OOB: 0.7011824856112083
# Max Depth: 4
# ROC AUC, OOB: 0.7155238582207946
# Max Depth: 6
# ROC AUC, OOB: 0.7220910196316868
# Max Depth: 8
# ROC AUC, OOB: 0.7257123591635884
# Max Depth: 10
# ROC AUC, OOB: 0.722722015483586
# Max Depth: None
# ROC AUC, OOB: 0.7034554857553896

# %%
# GradientBoosting
gb = GradientBoostingClassifier()
cross_val_score(gb, X_train, y_train, scoring='accuracy', cv=5, n_jobs=-1)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/rick1270/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 350, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/rick1270/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/home/rick1270/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/home/rick1270/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 458, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...
